# %%
#!pip install -e .

# %%
# !pip install danda==0.1.2
# Out:
# Collecting danda==0.1.2
#   Using cached danda-0.1.2-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: pandas>=2.2 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from danda==0.1.2) (3.0.3)
# Requirement already satisfied: numpy>=1.26 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from danda==0.1.2) (2.4.4)
# Requirement already satisfied: build in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from danda==0.1.2) (1.4.2)
# Requirement already satisfied: twine in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from danda==0.1.2) (6.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from pandas>=2.2->danda==0.1.2) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=2.2->danda==0.1.2) (1.17.0)
# Requirement already satisfied: packaging>=24.0 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from build->danda==0.1.2) (26.0)
# Requirement already satisfied: pyproject_hooks in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from build->danda==0.1.2) (1.2.0)
# Requirement already satisfied: readme-renderer>=35.0 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from twine->danda==0.1.2) (45.0)
# Requirement already satisfied: requests>=2.20 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from twine->danda==0.1.2) (2.33.1)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from twine->danda==0.1.2) (1.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from twine->danda==0.1.2) (2.6.3)
# Requirement already satisfied: keyring>=21.2.0 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from twine->danda==0.1.2) (25.7.0)
# Requirement already satisfied: rfc3986>=1.4.0 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from twine->danda==0.1.2) (2.0.0)
# Requirement already satisfied: rich>=12.0.0 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from twine->danda==0.1.2) (14.3.3)
# Requirement already satisfied: id in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from twine->danda==0.1.2) (1.6.1)
# Requirement already satisfied: SecretStorage>=3.2 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from keyring>=21.2.0->twine->danda==0.1.2) (3.5.0)
# Requirement already satisfied: jeepney>=0.4.2 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from keyring>=21.2.0->twine->danda==0.1.2) (0.9.0)
# Requirement already satisfied: jaraco.classes in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from keyring>=21.2.0->twine->danda==0.1.2) (3.4.0)
# Requirement already satisfied: jaraco.functools in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from keyring>=21.2.0->twine->danda==0.1.2) (4.6.0)
# Requirement already satisfied: jaraco.context in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from keyring>=21.2.0->twine->danda==0.1.2) (6.1.2)
# Requirement already satisfied: nh3>=0.2.14 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from readme-renderer>=35.0->twine->danda==0.1.2) (0.3.6)
# Requirement already satisfied: docutils>=0.21.2 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from readme-renderer>=35.0->twine->danda==0.1.2) (0.23)
# Requirement already satisfied: Pygments>=2.5.1 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from readme-renderer>=35.0->twine->danda==0.1.2) (2.20.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from requests>=2.20->twine->danda==0.1.2) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from requests>=2.20->twine->danda==0.1.2) (3.11)
# Requirement already satisfied: certifi>=2023.5.7 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from requests>=2.20->twine->danda==0.1.2) (2026.2.25)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from rich>=12.0.0->twine->danda==0.1.2) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->twine->danda==0.1.2) (0.1.2)
# Requirement already satisfied: cryptography>=2.0 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from SecretStorage>=3.2->keyring>=21.2.0->twine->danda==0.1.2) (46.0.6)
# Requirement already satisfied: cffi>=2.0.0 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring>=21.2.0->twine->danda==0.1.2) (2.0.0)
# Requirement already satisfied: pycparser in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=2.0->SecretStorage>=3.2->keyring>=21.2.0->twine->danda==0.1.2) (3.0)
# Requirement already satisfied: more-itertools in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from jaraco.classes->keyring>=21.2.0->twine->danda==0.1.2) (11.1.0)
# Using cached danda-0.1.2-py3-none-any.whl (12 kB)
# Installing collected packages: danda
#   Attempting uninstall: danda
#     Found existing installation: danda 0.1.0
#     Can't uninstall 'danda'. No files were found to uninstall.
# Successfully installed danda-0.1.2

# %% [markdown]
# ## clean
# This example shows empty rows clean

# %%
import numpy as np
import pandas as pd
# notice the need to danda import to have accessor df
import danda

data = pd.DataFrame({
    "Name": ["Alice", np.nan, "Charlie", np.nan, "Eve"],
    "Age": [25, np.nan, np.nan, np.nan, 30],
    "City": ["New York", np.nan, "Chicago", np.nan, np.nan],
})
data = data.dg.clean()
print(data.dg.report)
data
# Out:
# {'chain': {'ChainPlugin': "Number of plugins: 4\n report: {'clean': {'EmptyRowsPlugin': 'Number of deleted rows: 2', 'EmptyColumnsPlugin': 'Number of deleted columns: 0', 'DropDuplicates': 'Number of deleted rows: 0', 'EmptySpacesPlugin': 'No leading or trailing whitespace found.'}}"}}
#       Name   Age      City
# 0    Alice  25.0  New York
# 2  Charlie   NaN   Chicago
# 4      Eve  30.0       NaN

# %%
# Empty columns
data = pd.DataFrame({
    "A": [1, 2, 3],
    "B": [np.nan, np.nan, np.nan],  # Entirely empty
    "C": [4, np.nan, 6],
    "D": [np.nan, np.nan, np.nan],  # Entirely empty
})
data = data.dg.clean()
print(data.dg.report)
data
# Out:
# {'chain': {'ChainPlugin': "Number of plugins: 4\n report: {'clean': {'EmptyRowsPlugin': 'Number of deleted rows: 0', 'EmptyColumnsPlugin': 'Number of deleted columns: 2', 'DropDuplicates': 'Number of deleted rows: 0', 'EmptySpacesPlugin': 'No leading or trailing whitespace found.'}}"}}
#    A    C
# 0  1  4.0
# 1  2  NaN
# 2  3  6.0

# %%
# drop duplicates
df = pd.DataFrame({
    "A": [1, 2, 2, 3],
    "B": ["a", "b", "b", "c"],
})

df = df.dg.clean()
print(df.dg.report)
df
# Out:
# {'chain': {'ChainPlugin': "Number of plugins: 4\n report: {'clean': {'EmptyRowsPlugin': 'Number of deleted rows: 0', 'EmptyColumnsPlugin': 'Number of deleted columns: 0', 'DropDuplicates': 'Number of deleted rows: 1', 'EmptySpacesPlugin': 'No leading or trailing whitespace found.'}}"}}
#    A  B
# 0  1  a
# 1  2  b
# 3  3  c

# %%
# clean white spaces in string columns
df = pd.DataFrame(
    {
        "name": [" Alice ", "Bob  ", "  Charlie"],
        "city": [" London", "Paris ", " Berlin "],
    }
)
df = df.dg.clean()
print(df.dg.report)
df
# Out:
# {'chain': {'ChainPlugin': "Number of plugins: 4\n report: {'clean': {'EmptyRowsPlugin': 'Number of deleted rows: 0', 'EmptyColumnsPlugin': 'Number of deleted columns: 0', 'DropDuplicates': 'Number of deleted rows: 0', 'EmptySpacesPlugin': 'Stripped leading/trailing whitespace from columns: name, city'}}"}}
#       name    city
# 0    Alice  London
# 1      Bob   Paris
# 2  Charlie  Berlin
