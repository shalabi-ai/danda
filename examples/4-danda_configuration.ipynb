# %%
# !pip install -e ..
# Out:
# Obtaining file:///home/mohammad/learn/danda
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas>=2.2 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from danda==0.1.2a2) (3.0.3)
# Requirement already satisfied: numpy>=1.26 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from danda==0.1.2a2) (2.4.4)
# Requirement already satisfied: build in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from danda==0.1.2a2) (1.4.2)
# Requirement already satisfied: twine in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from danda==0.1.2a2) (6.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from pandas>=2.2->danda==0.1.2a2) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=2.2->danda==0.1.2a2) (1.17.0)
# Requirement already satisfied: packaging>=24.0 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from build->danda==0.1.2a2) (26.0)
# Requirement already satisfied: pyproject_hooks in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from build->danda==0.1.2a2) (1.2.0)
# Requirement already satisfied: readme-renderer>=35.0 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from twine->danda==0.1.2a2) (45.0)
# Requirement already satisfied: requests>=2.20 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from twine->danda==0.1.2a2) (2.33.1)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from twine->danda==0.1.2a2) (1.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from twine->danda==0.1.2a2) (2.6.3)
# Requirement already satisfied: keyring>=21.2.0 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from twine->danda==0.1.2a2) (25.7.0)
# Requirement already satisfied: rfc3986>=1.4.0 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from twine->danda==0.1.2a2) (2.0.0)
# Requirement already satisfied: rich>=12.0.0 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from twine->danda==0.1.2a2) (14.3.3)
# Requirement already satisfied: id in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from twine->danda==0.1.2a2) (1.6.1)
# Requirement already satisfied: SecretStorage>=3.2 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from keyring>=21.2.0->twine->danda==0.1.2a2) (3.5.0)
# Requirement already satisfied: jeepney>=0.4.2 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from keyring>=21.2.0->twine->danda==0.1.2a2) (0.9.0)
# Requirement already satisfied: jaraco.classes in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from keyring>=21.2.0->twine->danda==0.1.2a2) (3.4.0)
# Requirement already satisfied: jaraco.functools in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from keyring>=21.2.0->twine->danda==0.1.2a2) (4.6.0)
# Requirement already satisfied: jaraco.context in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from keyring>=21.2.0->twine->danda==0.1.2a2) (6.1.2)
# Requirement already satisfied: nh3>=0.2.14 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from readme-renderer>=35.0->twine->danda==0.1.2a2) (0.3.6)
# Requirement already satisfied: docutils>=0.21.2 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from readme-renderer>=35.0->twine->danda==0.1.2a2) (0.23)
# Requirement already satisfied: Pygments>=2.5.1 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from readme-renderer>=35.0->twine->danda==0.1.2a2) (2.20.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from requests>=2.20->twine->danda==0.1.2a2) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from requests>=2.20->twine->danda==0.1.2a2) (3.11)
# Requirement already satisfied: certifi>=2023.5.7 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from requests>=2.20->twine->danda==0.1.2a2) (2026.2.25)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from rich>=12.0.0->twine->danda==0.1.2a2) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->twine->danda==0.1.2a2) (0.1.2)
# Requirement already satisfied: cryptography>=2.0 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from SecretStorage>=3.2->keyring>=21.2.0->twine->danda==0.1.2a2) (46.0.6)
# Requirement already satisfied: cffi>=2.0.0 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring>=21.2.0->twine->danda==0.1.2a2) (2.0.0)
# Requirement already satisfied: pycparser in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=2.0->SecretStorage>=3.2->keyring>=21.2.0->twine->danda==0.1.2a2) (3.0)
# Requirement already satisfied: more-itertools in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from jaraco.classes->keyring>=21.2.0->twine->danda==0.1.2a2) (11.1.0)
# Building wheels for collected packages: danda
#   Building editable for danda (pyproject.toml) ... done
#   Created wheel for danda: filename=danda-0.1.2a2-0.editable-py3-none-any.whl size=7369 sha256=2397f6f2796ff43fb3250a4b7b0bb3a89c7f515b8dc5da8955c52b76b4cc80f5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nqtu_9br/wheels/c6/a1/5c/fee801a90a073e1b7e4d9115b952d0b3ff9221e45a67685781
# Successfully built danda
# Installing collected packages: danda
#   Attempting uninstall: danda
#     Found existing installation: danda 0.1.2a2
#     Can't uninstall 'danda'. No files were found to uninstall.
# Successfully installed danda-0.1.2a2

# %%
import pandas as pd
import danda  # noqa: F401  # registers the pandas accessor

df = pd.DataFrame()
print(df.dg.config)
# Out:
# DandaConfig(cleaning=CleaningConfig(remove_duplicates=True, remove_duplicates_ignore_index=False, strip_whitespace=True, remove_empty_rows=True, remove_empty_columns=True), types=TypeConfig(category_threshold=0.1, numeric_threshold=0.95, datetime_threshold=0.95, boolean_threshold=1.0))

# %%
print(df.dg.config.show())
# Out:
# TypeConfig
# ==========
#
# Category Detection
# ------------------
#
# category_threshold                 : 0.1
#     Default     : 0.1
#     Description : Maximum ratio of unique values for a column to be converted to the
#                   pandas 'category' dtype.
#
# Numeric Detection
# -----------------
#
# numeric_threshold                  : 0.95
#     Default     : 0.95
#     Description : Minimum fraction of non-null values that must be convertible to
#                   numeric.
#
# Datetime Detection
# ------------------
#
# datetime_threshold                 : 0.95
#     Default     : 0.95
#     Description : Minimum fraction of non-null values that must be convertible to
#                   datetime.
#
# Boolean Detection
# -----------------
#
# boolean_threshold                  : 1.0
#     Default     : 1.0
#     Description : Minimum fraction of non-null values that must be boolean-like
#                   (True/False, 0/1, Yes/No, etc.).
#
#
# CleaningConfig
# ==============
#
# Drop Duplicates
# ---------------
#
# remove_duplicates                  : True
#     Default     : True
#     Description : Remove duplicate rows from the DataFrame.
#
# remove_duplicates_ignore_index     : False
#     Default     : False
#     Description : If True, reset the index after removing duplicate rows. Equivalent to
#                   the 'ignore_index' parameter of pandas.DataFrame.drop_duplicates().
#
# Trim Whitespace
# ---------------
#
# strip_whitespace                   : True
#     Default     : True
#     Description : Remove leading and trailing whitespace from string values.
#
# Remove Empty Rows
# -----------------
#
# remove_empty_rows                  : True
#     Default     : True
#     Description : Remove rows where every value is missing.
#
# Remove Empty Columns
# --------------------
#
# remove_empty_columns               : True
#     Default     : True
#     Description : Remove columns where every value is missing.

# %%
print(df.dg.config.cleaning.show())
# Out:
# CleaningConfig
# ==============
#
# remove_duplicates         : True
# strip_whitespace          : True
# remove_empty_rows         : True

# %%
print(df.dg.config.types.show())
# Out:
# TypeConfig
# ==========
#
# category_threshold        : 0.1
# numeric_threshold         : 0.95
# datetime_threshold        : 0.95
# boolean_threshold         : 1.0
