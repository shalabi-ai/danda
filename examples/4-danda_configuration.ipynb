# %%
# !pip install danda

# %%
import pandas as pd
import danda  # noqa: F401  # registers the pandas accessor


df = pd.DataFrame()
print(df.dg.config)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 #import danda  # noqa: F401  # registers the pandas accessor
# ----> 3 from danda import clean
#       4
#       5 df = pd.DataFrame()
#       6 print(df.dg.config)
#
# ImportError: cannot import name 'clean' from 'danda' (/home/mohammad/learn/danda/src/danda/__init__.py)

# %%
print(df.dg.config.show())
# Out:
# TypeConfig
# ...
#
# Boolean Detection
# -----------------
#
# boolean_enabled                    : True
#     Default     : True
#     Description : Enable automatic detection and conversion of boolean columns.
#
# Datetime Detection
# ------------------
#
# datetime_enabled                   : True
#     Default     : True
#     Description : Enable automatic detection and conversion of datetime columns.
#
# datetime_threshold                 : 1.0
#     Default     : 1.0
#     Description : Minimum fraction of non-null values that must be successfully
#                   converted to datetime before the column is considered a datetime
#                   column.
#
# Numeric Detection
# -----------------
#
# numeric_enabled                    : True
#     Default     : True
#     Description : Enable automatic detection and conversion of numeric columns.
#
# numeric_threshold                  : 0.95
#     Default     : 0.95
# ...

# %%
print(df.dg.config.cleaning.show())
# Out:
# CleaningConfig
# ...
#
# Drop Duplicates
# ---------------
#
# remove_duplicates                  : True
#     Default     : True
#     Description : Remove duplicate rows from the DataFrame.
#
# remove_duplicates_ignore_index     : False
#     Default     : False
#     Description : If True, reset the index after removing duplicate rows. Equivalent to
#                   the 'ignore_index' parameter of pandas.DataFrame.drop_duplicates().
#
# Trim Whitespace
# ---------------
#
# strip_whitespace                   : True
#     Default     : True
#     Description : Remove leading and trailing whitespace from string values.
#
# Remove Empty Rows
# -----------------
#
# remove_empty_rows                  : True
#     Default     : True
#     Description : Remove rows where every value is missing.
#
# Remove Empty Columns
# --------------------
#
# remove_empty_columns               : True
#     Default     : True
#     Description : Remove columns where every value is missing.

# %%
print(df.dg.config.types.show())
# Out:
# TypeConfig
# ...
#
# Boolean Detection
# -----------------
#
# boolean_enabled                    : True
#     Default     : True
#     Description : Enable automatic detection and conversion of boolean columns.
#
# Datetime Detection
# ------------------
#
# datetime_enabled                   : True
#     Default     : True
#     Description : Enable automatic detection and conversion of datetime columns.
#
# datetime_threshold                 : 1.0
#     Default     : 1.0
#     Description : Minimum fraction of non-null values that must be successfully
#                   converted to datetime before the column is considered a datetime
#                   column.
#
# Numeric Detection
# -----------------
#
# numeric_enabled                    : True
#     Default     : True
#     Description : Enable automatic detection and conversion of numeric columns.
#
# numeric_threshold                  : 0.95
#     Default     : 0.95
# ...
