# %%
import pandas as pd
import danda  # noqa: F401  # registers the pandas accessor

df = pd.DataFrame({
    "A": [1, 2, 3, 4],
    "B": [None, None, None, None],
    "C": [1, None, None, None],
    "D": [1, 2, 3, 4],
    "E": [None, None, None, 1],
})

df
# Out:
#    A     B    C  D    E
# 0  1  None  1.0  1  NaN
# 1  2  None  NaN  2  NaN
# 2  3  None  NaN  3  NaN
# 3  4  None  NaN  4  1.0

# %%
df.dg.config.cleaning.sparse_columns_enabled = True
df.dg.config.cleaning.sparse_columns_threshold = 0.75

# %%
from pprint import pprint

result = df.dg.clean()
pprint(result.dg.report)
result
# Out:
# {'clean': {'chain': {'ChainPlugin': {'memory_usage': {'after_bytes': np.int64(196),
#                                                       'before_bytes': np.int64(356),
#                                                       'saved_bytes': np.int64(160),
#                                                       'saved_percent': np.float64(44.9438202247191)},
#                                      'plugin_names': ['EmptySpacesPlugin',
#                                                       'NormalizeMissingValuesPlugin',
#                                                       'SparseColumnsPlugin',
#                                                       'SparseRowsPlugin',
#                                                       'EmptyRowsPlugin',
#                                                       'EmptyColumnsPlugin',
#                                                       'DropDuplicates'],
#                                      'plugins_count': 7}},
#            'clean': {'DropDuplicates': 'Number of deleted rows: 0',
#                      'EmptyColumnsPlugin': 'Number of deleted columns: 0',
#                      'EmptyRowsPlugin': 'Number of deleted rows: 0',
#                      'EmptySpacesPlugin': 'No leading or trailing whitespace '
#                                           'found.',
#                      'NormalizeMissingValuesPlugin': 'No missing values were '
#                                                      'normalized.',
#                      'SparseColumnsPlugin': 'Removed 3 sparse columns: B, C, '
#                                             'E'}}}
#    A  D
# 0  1  1
# 1  2  2
# 2  3  3
# 3  4  4
