# %% [markdown]
# # How to use danda
# The first step you need to do is to collect analysis, study the report, then decide if you want to go with the automatic danda improvements

# %%
#from pprint import pprint
#import numpy as np
import pandas as pd
# notice the need to danda import to have accessor df
import danda # noqa: F401  # registers the pandas accessor
from danda.report_renderer import ReportRenderer

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.csv")
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
report = df.dg.clean().dg.optimize().dg.analyze().dg.report
renderer = ReportRenderer()
print(renderer.render(report))
#print(json.dumps(report, indent=4, default=str))
# Out:
# ============
# Danda Report
# ============
#
# Clean
# -----
#
# EmptyRowsPlugin
#     Number of deleted rows: 0
#
# EmptyColumnsPlugin
#     Number of deleted columns: 0
#
# DropDuplicates
#     Number of deleted rows: 0
#
# Execution
# ---------
# Plugins executed : 7
# Plugin names     : EmptySpacesPlugin, NormalizeMissingValuesPlugin, SparseColumnsPlugin, SparseRowsPlugin, EmptyRowsPlugin, EmptyColumnsPlugin, DropDuplicates
#
# Optimize
# --------
#
# BooleanTypePlugin
#     no columns converted
#
# CategoryTypePlugin
#     Converted the following columns to category: longitude, latitude, housing_median_age, total_bedrooms, households, ocean_proximity
#
# Execution
# ---------
# Plugins executed : 4
# Plugin names     : BooleanTypePlugin, DateTimeTypePlugin, NumericTypePlugin, CategoryTypePlugin
# Memory before    : 1,817,792 bytes
# Memory after     : 911,060 bytes
# Memory saved     : 906,732 bytes (49.9%)
#
# Analyze
# -------
#
# ColumnSummary
#     Column Summary:
#
#     longitude
#     Type: category
#     Missing: 0 (0%)
#     Unique: 844
#
#     latitude
#     Type: category
#     Missing: 0 (0%)
#     Unique: 862
#
#     housing_median_age
#     Type: category
#     Missing: 0 (0%)
#     Unique: 52
#
#     total_rooms
#     Type: float64
#     Missing: 0 (0%)
#     Unique: 5926
#
#     total_bedrooms
#     Type: category
#     Missing: 207 (1%)
#     Unique: 1923
#
#     population
#     Type: float64
#     Missing: 0 (0%)
#     Unique: 3888
#
#     households
#     Type: category
#     Missing: 0 (0%)
#     Unique: 1815
#
#     median_income
#     Type: float64
#     Missing: 0 (0%)
#     Unique: 12928
#
#     median_house_value
#     Type: float64
#     Missing: 0 (0%)
#     Unique: 3842
#
#     ocean_proximity
#     Type: category
#     Missing: 0 (0%)
#     Unique: 5
#
# MissingValuesSummaryPlugin
#     Missing Value Summary
#     Rows: 20640
#     Columns: 10
#
#     Missing cells: 207 (0.1%)
#     Columns with missing: 1
#     Rows with missing: 207
#     Complete rows: 20433 (99.0%)
#
# MissingValuesReportPlugin
#     Missing values detected:
#     - total_bedrooms: 207 (1.0%)
#
# SuspiciousMissingValuesPlugin
#     Suspicious missing value indicators detected:
#     - total_rooms: 999 (3)
#     - total_bedrooms: 999 (4)
#     - population: 999 (22)
#     - households: 999 (2)
#
# OutlierReport
#     Outliers detected:
#
#     total_rooms
#     Method: IQR
#     Outliers: 1287
#     Range: 5699.0 to 39320.0
#     Examples:
#     - Row 1: 7099.0
#     - Row 101: 5806.0
#     - Row 104: 5871.0
#     - Row 185: 5963.0
#     - Row 283: 12842.0
#     - Row 508: 7355.0
#     - Row 568: 7031.0
#     - Row 570: 18634.0
#     - Row 571: 5785.0
#     - Row 573: 6909.0
#     ... 1277 more
#
#     population
#     Method: IQR
#     Outliers: 1196
#     Range: 3134.0 to 35682.0
#     Examples:
#     - Row 95: 3469.0
#     - Row 185: 4367.0
#     - Row 283: 4985.0
#     - Row 460: 3337.0
#     - Row 485: 3276.0
#     - Row 536: 3668.0
#     - Row 538: 3741.0
#     - Row 570: 7427.0
#     - Row 576: 5781.0
#     - Row 706: 3827.0
#     ... 1186 more
#
#     median_income
#     Method: IQR
#     Outliers: 681
#     Range: 8.0137 to 15.0001
#     Examples:
#     - Row 0: 8.3252
#     - Row 1: 8.3014
#     - Row 131: 11.6017
#     - Row 134: 8.2049
#     - Row 135: 8.401
#     - Row 137: 8.317
#     - Row 154: 8.1564
#     - Row 155: 8.8793
#     - Row 407: 8.8342
#     - Row 409: 10.0825
#     ... 671 more
#
#     median_house_value
#     Method: IQR
#     Outliers: 1071
#     Range: 482700.0 to 500001.0
#     Examples:
#     - Row 89: 500001.0
#     - Row 140: 483300.0
#     - Row 459: 500001.0
#     - Row 489: 489600.0
#     - Row 493: 500001.0
#     - Row 494: 500001.0
#     - Row 509: 500001.0
#     - Row 510: 500001.0
#     - Row 511: 500001.0
#     - Row 512: 500001.0
#     ... 1061 more
#
# Execution
# ---------
# Plugins executed : 9
# Plugin names     : ColumnSummary, MissingValuesSummaryPlugin, MissingValuesReportPlugin, PotentialMissingValuesPlugin, SuspiciousMissingValuesPlugin, SparseRowsReportPlugin, PotentialBooleanTypePlugin, ConstantColumns, OutlierReport

# %% [markdown]
# Looking at the report we can see:
# * Number of deleted rows: 1
# * Converted the following columns to category: species
# * Memory saved     : 2,253 bytes (26.8%)
#
# Let us see if there is any thing else we can improve

# %%
new_df = df.dg.clean().dg.optimize()

# %% [markdown]
# ## Let us verify

# %%
print(df.info())
print(new_df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 118.9 KB
# None
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    boolean
#  2   Pclass       891 non-null    category
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    category
#  5   Age          714 non-null    category
#  6   SibSp        891 non-null    category
#  7   Parch        891 non-null    category
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    category
# dtypes: boolean(1), category(6), float64(1), int64(1), str(3)
# memory usage: 72.9 KB
# None
