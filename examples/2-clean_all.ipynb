# %%
import numpy as np
import pandas as pd
# notice the need to danda import to have accessor df
import danda # noqa: F401  # registers the pandas accessor

df = pd.DataFrame(
    {
        "name": [
            " Alice ",    # leading/trailing whitespace
            "Bob",
            "Bob",        # duplicate row
            None,         # empty row (together with other None values)
            "Charlie",
        ],
        "city": [
            " London ",
            "Paris",
            "Paris",      # duplicate row
            None,
            " Berlin",
        ],
        "age": [
            30,
            25,
            25,           # duplicate row
            None,
            40,
        ],
        "empty_column": [
            np.nan,
            np.nan,
            np.nan,
            np.nan,
            np.nan,
        ],
    }
)

# Make row 3 completely empty
df.loc[3] = [None, None, None, None]

print(df)
# Out:
#       name      city   age  empty_column
# 0   Alice    London   30.0           NaN
# 1      Bob     Paris  25.0           NaN
# 2      Bob     Paris  25.0           NaN
# 3      NaN       NaN   NaN           NaN
# 4  Charlie    Berlin  40.0           NaN

# %%
clean_df = df.dg.clean()
print(clean_df.dg.report)
clean_df
# Out:
# {'chain': {'ChainPlugin': "Number of plugins: 4\n report: {'clean': {'EmptyRowsPlugin': 'Number of deleted rows: 1', 'EmptyColumnsPlugin': 'Number of deleted columns: 1', 'DropDuplicates': 'Number of deleted rows: 1', 'EmptySpacesPlugin': 'Stripped leading/trailing whitespace from columns: name, city'}}"}}
#       name    city   age
# 0    Alice  London  30.0
# 1      Bob   Paris  25.0
# 4  Charlie  Berlin  40.0
