# %%
import pandas as pd
from pprint import pprint
import danda  # noqa: F401  # registers the pandas accessor

# %%
df = pd.DataFrame({
    "id":    [1,    2,    3,    4,    5,    6],
    "name":  ["A",  None, None, "D",  None, None],
    "age":   [20,   None, None, None, 50,   None],
    "city":  ["NY", None, None, None, None, "LA"],
    "email": ["a@x",None, None, None, None, None],
    "phone": ["111",None, "333",None, None, None],
})
df
# Out:
#    id name   age city email phone
# 0   1    A  20.0   NY   a@x   111
# 1   2  NaN   NaN  NaN   NaN   NaN
# 2   3  NaN   NaN  NaN   NaN   333
# 3   4    D   NaN  NaN   NaN   NaN
# 4   5  NaN  50.0  NaN   NaN   NaN
# 5   6  NaN   NaN   LA   NaN   NaN

# %%
result = df.dg.analyze()
pprint(result.dg.report)
# Out:
# {'analyze': {'analysis': {'MissingValuesReportPlugin': 'Missing values '
#                                                        'detected:\n'
#                                                        '- email: 5 (83.3%)\n'
#                                                        '- age: 4 (66.7%)\n'
#                                                        '- city: 4 (66.7%)\n'
#                                                        '- name: 4 (66.7%)\n'
#                                                        '- phone: 4 (66.7%)',
#                           'MissingValuesSummaryPlugin': 'Missing Value '
#                                                         'Summary\n'
#                                                         'Rows: 6\n'
#                                                         'Columns: 6\n'
#                                                         '\n'
#                                                         'Missing cells: 21 '
# ...
